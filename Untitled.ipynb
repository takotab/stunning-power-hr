# %%
import pandas as pd
import matplotlib.pyplot as plt
from fitparse import FitFile
import seaborn as sns
import utils
import json
from scipy import signal
from scipy import stats

# %%
utils.apply_to_fitfile(lambda x:print(x))
# Out:
# data/Stefan/2019-05-11/Stefan.2019-05-11.test_file.fit
# excecuted on Stefan

# %%
def fill_na(result,i):
    for key in result.keys():
        if i not in result[key]:
            result[key][i]=0
    return result
import numpy as np
def get_index(df, time=60, power=175):
    rolling_power = df.power.rolling(time).mean()
    a = np.abs( rolling_power-np.ones_like(rolling_power.array)) 
    argmin = np.argmin(a)
    print(argmin)
    return argmin

def get_joule(power ):
    return power.sum()
    
    
    
def plot_file(file):
    print(utils.get_name(file))
    result = {}
    fitfile = FitFile(file)
    
    # Get all data messages that are of type record
    for i,record in enumerate(fitfile.get_messages("record")):
        # Go through all the data entries in this record
        for record_data in record:
            if not str(record_data.name) in list(result.keys()):
                result[str(record_data.name)] = {}
                
            result[record_data.name][i] = record_data.value
        result = fill_na(result,i)
            
    df = pd.DataFrame().from_dict(result)
    fig =  plt.figure(figsize=(20,20))
    df.loc[:,['cadence','power','heart_rate']].plot()
    
    df.to_csv(file.replace('.fit','.csv'))
    info = utils.get_info(file)
    
    start = int(info['start(sec)'])
    end = int(info['end(sec)'])
    
    
    
    fig = plt.figure(figsize=(16,16)) # Create matplotlib figure

    ax = fig.add_subplot(111) # Create matplotlib axes
    ax2 = ax.twinx() # Create another axes that shares the same x-axis as ax.
    df.loc[start:end,['power']].plot(color='purple', ax=ax)
    patches, labels = ax.get_legend_handles_labels()

    ax.legend(patches, labels, loc='upper left')
    df.loc[start:end,['heart_rate']].plot(color='red', ax=ax2)
    df.loc[start:end,['cadence']].plot(color='blue', ax=ax2)

    ax.set_ylabel('Power (W)')
    ax2.set_ylabel('Heart rate / Cadance (Bpm)')
    ax.set_xlabel('Tijd (sec)')
    
    plt.show()
    fig.savefig(file.replace('.fit','_plot.png').replace('.',''), dpi=fig.dpi)
    
    info['total work (J)']=str(df.loc[start:end,'power'].array.sum())
    info['Max hartslag'] = df.loc[start:end+30,'heart_rate'].rolling(30).mean().max()
    info['Max power (30 sec)'] = df.loc[start:end+30,'power'].rolling(30).mean().max()
    if not info['gewicht(kg)'] == 'Onbekend':
        total[utils.get_name(file)]= np.round(info['Max power (30 sec)']/float(info['gewicht(kg)']),2 )
    
    info['hr-zones'] = {}
    info['hr-zones']['Herstel training (H)']= [info['Max hartslag']*.50,info['Max hartslag']*.65]
    info['hr-zones']['Extensieve duurtraining (D1)']= [info['Max hartslag']*.65,info['Max hartslag']*.75]
    info['hr-zones']['Intensieve duurtraining (D2)']= [info['Max hartslag']*.75,info['Max hartslag']*.85]
    info['hr-zones']['Extensieve herhalingen (D3)']= [info['Max hartslag']*.85,info['Max hartslag']*.95]
    info['hr-zones']['Intensieve herh/interval (HIIT)']= [info['Max hartslag']*.95,info['Max hartslag']*1]
    
    for key, item in info['hr-zones'].items():
        info['hr-zones'][key] = (int(item[0]),int(item[1]))
        
    
    utils.set_info(file,info)
    
    
    print(info)
    
    
total={}
utils.apply_to_fitfile(plot_file,all=True)
# Out:
# Stefan
# {'gewicht(kg)': '112.5', 'start(sec)': '238', 'end(sec)': '1100', 'total work (J)': '291169', 'Max hartslag': 178.53333333333333, 'Max power (30 sec)': 515.8, 'hr-zones': {'Herstel training (H)': (89, 116), 'Extensieve duurtraining (D1)': (116, 133), 'Intensieve duurtraining (D2)': (133, 151), 'Extensieve herhalingen (D3)': (151, 169), 'Intensieve herh/interval (HIIT)': (169, 178)}}
# excecuted on Stefan
# Eric
# {'gewicht(kg)': '80', 'start(sec)': '244', 'end(sec)': '800', 'test': '0.8880965670178816', 'total work (J)': '153765.0', 'Max hartslag': 157.2, 'Max power (30 sec)': 385.3, 'hr-zones': {'Herstel training (H)': (78, 102), 'Extensieve duurtraining (D1)': (102, 117), 'Intensieve duurtraining (D2)': (117, 133), 'Extensieve herhalingen (D3)': (133, 149), 'Intensieve herh/interval (HIIT)': (149, 157)}}
# excecuted on Eric
# Roos
# {'gewicht(kg)': '58', 'start(sec)': '169', 'end(sec)': '580', 'total work (J)': '85731', 'Max hartslag': 190.96666666666667, 'Max power (30 sec)': 253.73333333333332, 'hr-zones': {'Herstel training (H)': (95, 124), 'Extensieve duurtraining (D1)': (124, 143), 'Intensieve duurtraining (D2)': (143, 162), 'Extensieve herhalingen (D3)': (162, 181), 'Intensieve herh/interval (HIIT)': (181, 190)}}
# excecuted on Roos
# Thijs
# {'gewicht(kg)': '86', 'start(sec)': '240', 'end(sec)': '900', 'total work (J)': '195951', 'Max hartslag': 209.4, 'Max power (30 sec)': 424.56666666666666, 'hr-zones': {'Herstel training (H)': (104, 136), 'Extensieve duurtraining (D1)': (136, 157), 'Intensieve duurtraining (D2)': (157, 177), 'Extensieve herhalingen (D3)': (177, 198), 'Intensieve herh/interval (HIIT)': (198, 209)}}
# excecuted on Thijs
# Femke
# {'gewicht(kg)': '60', 'start(sec)': '244', 'end(sec)': '665', 'total work (J)': '103967', 'Max hartslag': 192.26666666666668, 'Max power (30 sec)': 323.6333333333333, 'hr-zones': {'Herstel training (H)': (96, 124), 'Extensieve duurtraining (D1)': (124, 144), 'Intensieve duurtraining (D2)': (144, 163), 'Extensieve herhalingen (D3)': (163, 182), 'Intensieve herh/interval (HIIT)': (182, 192)}}
# excecuted on Femke
# Marko
# {'gewicht(kg)': '73', 'start(sec)': '214', 'end(sec)': '810', 'total work (J)': '168900', 'Max hartslag': 194.36666666666667, 'Max power (30 sec)': 399.1, 'hr-zones': {'Herstel training (H)': (97, 126), 'Extensieve duurtraining (D1)': (126, 145), 'Intensieve duurtraining (D2)': (145, 165), 'Extensieve herhalingen (D3)': (165, 184), 'Intensieve herh/interval (HIIT)': (184, 194)}}
# excecuted on Marko
# Tako
# {'gewicht(kg)': '75', 'start(sec)': '281', 'end(sec)': '1044', 'total work (J)': '243548.0', 'Max hartslag': 179.9, 'Max power (30 sec)': 472.56666666666666, 'hr-zones': {'Herstel training (H)': (89, 116), 'Extensieve duurtraining (D1)': (116, 134), 'Intensieve duurtraining (D2)': (134, 152), 'Extensieve herhalingen (D3)': (152, 170), 'Intensieve herh/interval (HIIT)': (170, 179)}}
# excecuted on Tako
# Dennis
# {'gewicht(kg)': '78', 'start(sec)': '244', 'end(sec)': '865', 'total work (J)': '178455', 'Max hartslag': 178.2, 'Max power (30 sec)': 399.3333333333333, 'hr-zones': {'Herstel training (H)': (89, 115), 'Extensieve duurtraining (D1)': (115, 133), 'Intensieve duurtraining (D2)': (133, 151), 'Extensieve herhalingen (D3)': (151, 169), 'Intensieve herh/interval (HIIT)': (169, 178)}}
# excecuted on Dennis
# Lynn
# {'gewicht(kg)': '65', 'start(sec)': '250', 'end(sec)': '640', 'total work (J)': '93853', 'Max hartslag': 194.93333333333334, 'Max power (30 sec)': 316.4, 'hr-zones': {'Herstel training (H)': (97, 126), 'Extensieve duurtraining (D1)': (126, 146), 'Intensieve duurtraining (D2)': (146, 165), 'Extensieve herhalingen (D3)': (165, 185), 'Intensieve herh/interval (HIIT)': (185, 194)}}
# excecuted on Lynn
# Ruben
# {'gewicht(kg)': '75', 'start(sec)': '244', 'end(sec)': '902', 'total work (J)': '195312', 'Max hartslag': 199.3, 'Max power (30 sec)': 424.6, 'hr-zones': {'Herstel training (H)': (99, 129), 'Extensieve duurtraining (D1)': (129, 149), 'Intensieve duurtraining (D2)': (149, 169), 'Extensieve herhalingen (D3)': (169, 189), 'Intensieve herh/interval (HIIT)': (189, 199)}}
# excecuted on Ruben
# Mitchell
# {'gewicht(kg)': '60', 'start(sec)': '244', 'end(sec)': '734', 'total work (J)': '129135', 'Max hartslag': 195.76666666666668, 'Max power (30 sec)': 366.6333333333333, 'hr-zones': {'Herstel training (H)': (97, 127), 'Extensieve duurtraining (D1)': (127, 146), 'Intensieve duurtraining (D2)': (146, 166), 'Extensieve herhalingen (D3)': (166, 185), 'Intensieve herh/interval (HIIT)': (185, 195)}}
# excecuted on Mitchell
# Divera
# {'gewicht(kg)': '65', 'start(sec)': '267', 'end(sec)': '385', 'total work (J)': '22355', 'Max hartslag': 0.0, 'Max power (30 sec)': 200.5, 'hr-zones': {'Herstel training (H)': (0, 0), 'Extensieve duurtraining (D1)': (0, 0), 'Intensieve duurtraining (D2)': (0, 0), 'Extensieve herhalingen (D3)': (0, 0), 'Intensieve herh/interval (HIIT)': (0, 0)}}
# excecuted on Divera
# Lieke
# {'gewicht(kg)': '55', 'start(sec)': '246', 'end(sec)': '491', 'total work (J)': '51948', 'Max hartslag': 182.16666666666666, 'Max power (30 sec)': 251.43333333333334, 'hr-zones': {'Herstel training (H)': (91, 118), 'Extensieve duurtraining (D1)': (118, 136), 'Intensieve duurtraining (D2)': (136, 154), 'Extensieve herhalingen (D3)': (154, 173), 'Intensieve herh/interval (HIIT)': (173, 182)}}
# excecuted on Lieke
# Ronald
# {'gewicht(kg)': '74', 'start(sec)': '246', 'end(sec)': '734', 'total work (J)': '127071', 'Max hartslag': 175.33333333333334, 'Max power (30 sec)': 362.43333333333334, 'hr-zones': {'Herstel training (H)': (87, 113), 'Extensieve duurtraining (D1)': (113, 131), 'Intensieve duurtraining (D2)': (131, 149), 'Extensieve herhalingen (D3)': (149, 166), 'Intensieve herh/interval (HIIT)': (166, 175)}}
# excecuted on Ronald
# Ruud
# {'gewicht(kg)': 'Onbekend', 'start(sec)': '250', 'end(sec)': '730', 'total work (J)': '122813', 'Max hartslag': 186.93333333333334, 'Max power (30 sec)': 341.3666666666667, 'hr-zones': {'Herstel training (H)': (93, 121), 'Extensieve duurtraining (D1)': (121, 140), 'Intensieve duurtraining (D2)': (140, 158), 'Extensieve herhalingen (D3)': (158, 177), 'Intensieve herh/interval (HIIT)': (177, 186)}}
# excecuted on Ruud

# %%
sorted_by_value = sorted(total.items(), key=lambda kv: kv[1])

# %%
sorted_by_value
# Out:
# [('Divera', 3.08),
#  ('Roos', 4.37),
#  ('Lieke', 4.57),
#  ('Stefan', 4.58),
#  ('Eric', 4.82),
#  ('Lynn', 4.87),
#  ('Ronald', 4.9),
#  ('Thijs', 4.94),
#  ('Dennis', 5.12),
#  ('Femke', 5.39),
#  ('Marko', 5.47),
#  ('Ruben', 5.66),
#  ('Mitchell', 6.11),
#  ('Tako', 6.3)]

# %%
json.dump(sorted_by_value,open('data/vu test 11-05/overall.json','w'))
